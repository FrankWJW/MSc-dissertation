# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
# from keras.layers import Dense, Dropout, Activation, LSTM, Convolution1D, MaxPooling1D, Flatten
# from keras.models import Sequential
import matplotlib.pyplot as plt

# %matplotlib inline
from torchbearer import Trial
import os
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch
import torch.nn.functional as F
import torchvision.transforms as transforms
import torchbearer
from torch import nn
from torch import optim
from torch.utils.data import DataLoader, TensorDataset, Dataset
from torchvision.datasets import MNIST
from torchbearer import Trial
import torchvision.transforms as transforms

# %%
datapath = os.path.join(os.getcwd(), 'data')
datapath
# Out:
# 'D:\\projects\\Stock-Market-Price-Prediction-master\\data'

# %%
df = pd.read_csv(os.path.join(datapath,'Integrated Data.csv'))
df.tail()
# Out:
#             Date    Adj Close      Volume  2-days Net change  \
# 3016  2016/12/23  2263.790039  2020550000           2.830078
# 3017  2016/12/27  2268.879883  1987080000           5.089844
# 3018  2016/12/28  2249.919922  2392360000         -18.959961
# 3019  2016/12/29  2249.260010  2336370000          -0.659912
# 3020  2016/12/30  2238.830078  2670900000         -10.429932
#
#       5day-moving average  5day- standard deviation  10-day moving average  \
# 3016          2264.643994                  3.757096            2262.528003
# 3017          2265.913965                  3.932965            2263.719995
# 3018          2261.745947                  7.199588            2261.539990
# 3019          2258.561963                  8.671128            2261.137988
# 3020          2254.135986                 12.107894            2258.817993
#
#       10day- standard deviation  50-day moving average  \
# 3016                   5.773423            2185.648188
# 3017                   5.726416            2188.366187
# 3018                   6.446745            2190.834585
# 3019                   7.110240            2193.027783
# 3020                   9.989011            2194.918584
#
#       50day- standard deviation   ^VIX   ^TNX
# 3016                  54.155056  11.44  2.543
# 3017                  54.863455  11.99  2.563
# 3018                  54.799583  12.95  2.506
# 3019                  54.901540  13.37  2.477
# 3020                  54.816670  14.04  2.446

# %% [markdown]
# # build binary classifier

# %%
# -1 --> tomorrow goes down 
# 0 --> tomorrow goes up
# initialising
df['forecasting'] = 0

df['forecasting_10daysout'] = float('nan')
df['forecasting_20daysout'] = float('nan')
df['forecasting_30daysout'] = float('nan')
# if y > sp500: predict as go up
# else predict as go down
for i in df.index:
    try:
        if df['Adj Close'][i+1] > df['Adj Close'][i]:  # will go up?
            df.at[i, 'forecasting'] = 1
        else:
            df.at[i, 'forecasting'] = 0
    except:
        print('rearch the end')
        
for i in df.index:
    try:
        if df['Adj Close'][i+10] > df['Adj Close'][i]:  # will go up?
            df.at[i, 'forecasting_10daysout'] = 1
        else:
            df.at[i, 'forecasting_10daysout'] = 0
    except:
        print('rearch the end')
for i in df.index:
    try:
        if df['Adj Close'][i+20] > df['Adj Close'][i]:  # will go up?
            df.at[i, 'forecasting_20daysout'] = 1
        else:
            df.at[i, 'forecasting_20daysout'] = 0
    except:
        print('rearch the end')
for i in df.index:
    try:
        if df['Adj Close'][i+30] > df['Adj Close'][i]:  # will go up?
            df.at[i, 'forecasting_30daysout'] = 1
        else:
            df.at[i, 'forecasting_30daysout'] = 0
    except:
        print('rearch the end')

        
df = df.dropna(axis=0)
# Out:
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the end
# rearch the
# 2980                    1.0                    1.0                    1.0
# 2981                    1.0                    1.0                    1.0
# 2982                    1.0                    1.0                    1.0
# 2983                    1.0                    1.0                    1.0
# 2984                    1.0                    1.0                    1.0
# 2985                    1.0                    1.0                    1.0
# 2986                    1.0                    1.0                    1.0
# 2988                    1.0                    1.0                    1.0
# 2989                    1.0                    1.0                    1.0
# 2990                    1.0                    1.0                    1.0
#
# [2938 rows x 16 columns]

# %% [markdown]
# Now instead of set the next day's value as target,
# we will set the forecasting as target

# %%
print(len(df))
X = df.values[:,1:-4]
y = df.values[:,-1] # 30_days ahead forecasting
print(X.shape, y.shape)
# Out:
# 2938
# (2938, 11) (2938,)

# %%
X
# Out:
# array([[1197.75, 1513530000, -9.079956, ..., 14.63291434, 13.15, 4.542],
#        [1188.069946, 1653190000, -9.680054, ..., 14.62472792, 13.49,
#         4.518],
#        [1190.209961, 1581930000, 2.140015, ..., 14.60842001, 13.29, 4.47],
#        ...,
#        [2164.199951, 5367200000, -0.25, ..., 22.14454909, 14.48, 2.222],
#        [2180.389893, 4543860000, 16.189942000000002, ..., 21.93060761,
#         13.37, 2.238],
#        [2176.939941, 3830590000, -3.4499519999999997, ..., 21.61776338,
#         13.72, 2.2230000000000003]], dtype=object)

# %% [markdown]
# # testing train_test_split.py

# %%
from train_test_split import utility_fun

# %%
temp = utility_fun([X, y], len_of_trainset = 2000, time_interval = 20, batch_size=32)

temp.norm()
temp.sepera_time_step()
temp.test_train_split()
trainloader, validateData, trainData, testData = temp.build_dataloader()
print(validateData.shape, trainData.shape, testData.shape)
# Out:
# torch.Size([919, 1, 20, 11]) torch.Size([2000, 1, 20, 11]) torch.Size([2000, 1])

# %%
trainData.shape
a = trainData.view(2000, -1, 11)

# %%
b = a[:,0,:]

for i in range(11):
    plt.plot(b[:,i].numpy())

# %% [markdown]
# # create model and training

# %%
# define baseline MLP model
class BaselineModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(BaselineModel, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size) 
        self.fc2 = nn.Linear(hidden_size, num_classes)  
    
    def forward(self, x):
        out = self.fc1(x)
        out = F.relu(out)        
        out = self.fc2(out)
        out = F.sigmoid(out)
        out = out.squeeze()
        return out

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"

model = BaselineModel(20*11, 220, 1)

# define the loss function and the optimiser
# loss_function = nn.MSELoss()

#classification problem  we use bce loss
loss_function = nn.BCELoss()
optimiser = optim.Adam(model.parameters())

trial = Trial(model, optimiser, loss_function, metrics=['loss', 'accuracy']).to(device)
trial.with_generators(trainloader)
trial.run(epochs=10)
# Out:
# HBox(children=(IntProgress(value=0, description='0/10(t)', max=63, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='1/10(t)', max=63, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='2/10(t)', max=63, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='3/10(t)', max=63, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='4/10(t)', max=63, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='5/10(t)', max=63, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='6/10(t)', max=63, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='7/10(t)', max=63, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='8/10(t)', max=63, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='9/10(t)', max=63, style=ProgressStyle(description_width='init…
# [{'running_loss': 0.6680605411529541,
#   'running_binary_acc': 0.6393749713897705,
#   'loss': 0.666882336139679,
#   'binary_acc': 0.64000004529953,
#   'train_steps': 63,
#   'validation_steps': None},
#  {'running_loss': 0.6402671933174133,
#   'running_binary_acc': 0.6468749642372131,
#   'loss': 0.643975555896759,
#   'binary_acc': 0.6415000557899475,
#   'train_steps': 63,
#   'validation_steps': None},
#  {'running_loss': 0.6324930191040039,
#   'running_binary_acc': 0.6499999761581421,
#   'loss': 0.6325951814651489,
#   'binary_acc': 0.6500000357627869,
#   'train_steps': 63,
#   'validation_steps': None},
#  {'running_loss': 0.6095396280288696,
#   'running_binary_acc': 0.6706249713897705,
#   'loss': 0.6132064461708069,
#   'binary_acc': 0.6675000190734863,
#   'train_steps': 63,
#   'validation_steps': None},
#  {'running_loss': 0.6040788292884827,
#   'running_binary_acc': 0.6806249618530273,
#   'loss': 0.6085147857666016,
#   'binary_acc': 0.6770000457763672,
#   'train_steps': 63,
#   'validation_steps': None},
#  {'running_loss': 0.6037610769271851,
#   'running_binary_acc': 0.684374988079071,
#   'loss': 0.6019976139068604,
#   'binary_acc': 0.6810000538825989,
#   'train_steps': 63,
#   'validation_steps': None},
#  {'running_loss': 0.5960528254508972,
#   'running_binary_acc': 0.6787499785423279,
#   'loss': 0.5922448039054871,
#   'binary_acc': 0.6825000047683716,
#   'train_steps': 63,
#   'validation_steps': None},
#  {'running_loss': 0.5834619402885437,
#   'running_binary_acc': 0.6868749856948853,
#   'loss': 0.5811106562614441,
#   'binary_acc': 0.6920000314712524,
#   'train_steps': 63,
#   'validation_steps': None},
#  {'running_loss': 0.5885597467422485,
#   'running_binary_acc': 0.6800000071525574,
#   'loss': 0.5847818851470947,
#   'binary_acc': 0.6850000619888306,
#   'train_steps': 63,
#   'validation_steps': None},
#  {'running_loss': 0.5738933682441711,
#   'running_binary_acc': 0.6993749737739563,
#   'loss': 0.5780025124549866,
#   'binary_acc': 0.7005000114440918,
#   'train_steps': 63,
#   'validation_steps': None}]

# %%
torch.save(model.state_dict(), "mlp_model")

# %% [markdown]
# # generate gradient

# %%
class gradient_generator():
    
    def __init__(self, model):
        
        self.loss = nn.BCELoss()
        self.model = model.to('cpu')
        self.gradients = None
        # Put model in evaluation mode
        self.model.eval()
        # Hook the first layer to get the gradient
        self.hook = self.hook_layers()
    def hook_layers(self):    
        def hook_function(module, grad_in, grad_out):
            print("hook called")
            self.gradients = grad_out[0]
#         print(list(self.model._modules.items()))
        first_layer = list(self.model._modules.items())[0][1]
        hook = first_layer.register_backward_hook(hook_function)
        return hook
    def generate_gradient(self, inputs, labels):
        self.model.zero_grad()
        output = self.model(inputs)
        loss = self.loss(output, labels)
        output.backward()
        
        self.hook.remove()
        return self.gradients
    

grad = torch.zeros((2000,220))
i = 0


for data in trainloader:
    # get the inputs
    inputs, labels = data
    ins = inputs[i,:]
    labs = labels[i]
#     print(inputs.shape, labels.shape)
    GG = gradient_generator(model)
    temp = GG.generate_gradient(ins, labs)
    grad[i,:] = temp
    i += 1
grad
# Out:
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# hook called
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-64-fd4c2d3c223d> in <module>
#      35     # get the inputs
#      36     inputs, labels = data
# ---> 37     ins = inputs[i,:]
#      38     labs = labels[i]
#      39 #     print(inputs.shape, labels.shape)
#
# IndexError: index 32 is out of bounds for dimension 0 with size 32

# %% [markdown]
# # Visualisation

# %%
plt.plot(df['forecasting_30daysout'])

# %%
df.head()

# %%
from sklearn import preprocessing

df_norm = df.drop(columns=['Date','forecasting','forecasting_10daysout','forecasting_20daysout','forecasting_30daysout'],axis=0)
x = df_norm.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_norm = pd.DataFrame(x_scaled)

# %%
df_norm[0:20]

# %%
plt.imshow(df_norm[0:30], cmap=plt.get_cmap('gray'))

# %% [markdown]
# # sliding windows

# %%
from train_test_split import utility_fun

#classification problem  we use bce loss
loss_function = nn.BCELoss()
optimiser = optim.Adam(model.parameters())
device = "cuda:0" if torch.cuda.is_available() else "cpu"
cor = 0
mis = 0
for i in range(2000, 2500):
    temp = utility_fun([X, y], len_of_trainset = i, time_interval = 50)

    temp.norm()
    temp.sepera_time_step()
    temp.test_train_split()
    trainloader, validateData,_ ,_ = temp.build_dataloader()

    model = BaselineModel(550, 500, 1)
     
    trial = Trial(model, optimiser, loss_function, metrics=['loss', 'accuracy'], verbose = False).to(device)
    trial.with_generators(trainloader)
    trial.run(epochs=2)
    
    y_pred= model(validateData.view(validateData.shape[0],-1)[0].to(device).float())
    if y_pred.data > 0.5:
        a = 1
    else:
        a = 0
    if a == y[i]:
        cor += 1
    else:
        mis += 1
        
    print("the {}th day, pred: {} ---- true: {} ====== correct: {} ---- miscorrect: {}".format(i, a, y[i],cor,mis))
